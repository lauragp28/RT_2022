# %%
# ejecuto solo 1 vez al inicio

# para cada estrategia creamos un df vacio para almacenar los resultados, y lo almacenaremos en pickle
df_out = pd.DataFrame(columns=['date', 'open', 'high', 'low', 'close', 'in_condition_1','in_condition_2', 'out_condition_1', 'out_condition_2', 'signal_in', 'signal_out', 
'pos_before_order', 'order_sent', 'open_pos', 'filled_price', 'pnl'])

df_out.to_pickle('df_out_1.pkl')
df_out.to_pickle('df_out_2.pkl')
df_out.to_pickle('df_out_3.pkl')
df_out.to_pickle('df_out_4.pkl')
df_out.to_pickle('df_out_5.pkl')
df_out.to_pickle('df_out_6.pkl')
df_out.to_pickle('df_out_7.pkl')
df_out.to_pickle('df_out_8.pkl')
df_out.to_pickle('df_out_9.pkl')
df_out.to_pickle('df_out_10.pkl')
df_out.to_pickle('df_out_11.pkl')
df_out.to_pickle('df_out_12.pkl')
df_out.to_pickle('df_out_13.pkl')
df_out.to_pickle('df_out_14.pkl')
df_out.to_pickle('df_out_15.pkl')
df_out.to_pickle('df_out_16.pkl')
df_out.to_pickle('df_out_17.pkl')
df_out.to_pickle('df_out_18.pkl')
df_out.to_pickle('df_out_19.pkl')
df_out.to_pickle('df_out_20.pkl')
df_out.to_pickle('df_out_21.pkl')
df_out.to_pickle('df_out_22.pkl')
#df_out.to_pickle('df_out_31.pkl')

# %%
import pandas as pd
import numpy as np
from IPython.display import display
from ib_insync import *
import time

import warnings
warnings.filterwarnings("ignore")

# %%
# podemos monitorizar los datos recibidos
df_data = pd.read_pickle('df_data_2.pkl')
#df_data.tail(20)
display(df_data)
# Out:
#                   date     open     high      low    close  two_bars_up  \
# 0  2022-05-25 00:00:00  110.390  110.680  110.135  110.520        False
# 1  2022-05-25 01:00:00  110.520  110.930  110.495  110.595         True
# 2  2022-05-25 02:00:00  110.595  110.620  110.300  110.465        False
# 3  2022-05-25 03:00:00  110.465  111.040  110.290  111.005        False
# 4  2022-05-25 04:00:00  111.005  111.160  110.730  111.020         True
# ..                 ...      ...      ...      ...      ...          ...
# 65 2022-05-27 19:00:00  114.545  114.865  114.245  114.750         True
# 66 2022-05-27 20:00:00  114.750  115.295  114.545  114.895         True
# 67 2022-05-27 21:00:00  114.895  115.195  114.825  115.170         True
# 68 2022-05-27 22:00:00  115.170  115.220  114.985  115.060        False
# 69 2022-05-27 23:00:00  114.615  114.615  114.615  114.615        False
#
#         sma_12      sma_60    atr_14  in_condition_1  in_condition_2  \
# ...

# %%
# leemos todos los df_out
df_out_1 = pd.read_pickle('df_out_1.pkl')
df_out_2 = pd.read_pickle('df_out_2.pkl')
df_out_3 = pd.read_pickle('df_out_3.pkl')
df_out_4 = pd.read_pickle('df_out_4.pkl')
df_out_5 = pd.read_pickle('df_out_5.pkl')
df_out_6 = pd.read_pickle('df_out_6.pkl')
df_out_7 = pd.read_pickle('df_out_7.pkl')
df_out_8 = pd.read_pickle('df_out_8.pkl')
df_out_9 = pd.read_pickle('df_out_9.pkl')
df_out_10 = pd.read_pickle('df_out_10.pkl')
df_out_11 = pd.read_pickle('df_out_11.pkl')
df_out_12 = pd.read_pickle('df_out_12.pkl')
df_out_13 = pd.read_pickle('df_out_13.pkl')
df_out_14 = pd.read_pickle('df_out_14.pkl')
df_out_15 = pd.read_pickle('df_out_15.pkl')
df_out_16 = pd.read_pickle('df_out_16.pkl')
df_out_17 = pd.read_pickle('df_out_17.pkl')
df_out_18 = pd.read_pickle('df_out_18.pkl')
df_out_19 = pd.read_pickle('df_out_19.pkl')
df_out_20 = pd.read_pickle('df_out_20.pkl')
df_out_21 = pd.read_pickle('df_out_21.pkl')
df_out_22 = pd.read_pickle('df_out_22.pkl')

# %%
df_pos = pd.DataFrame(np.zeros((22,1)), columns=['open_pos'])
df_pos['open_pos'] = False

# comenzamos el indice en 1
df_pos.index = df_pos.index + 1

# %%
# leemos las ultimas posiciones de cada estrategia
df_pos.loc[1, 'open_pos'] = df_out_1.loc[df_out_1.index[-1], 'open_pos']
df_pos.loc[2, 'open_pos'] = df_out_2.loc[df_out_2.index[-1], 'open_pos']
df_pos.loc[3, 'open_pos'] = df_out_3.loc[df_out_3.index[-1], 'open_pos']
df_pos.loc[4, 'open_pos'] = df_out_4.loc[df_out_4.index[-1], 'open_pos']
df_pos.loc[5, 'open_pos'] = df_out_5.loc[df_out_5.index[-1], 'open_pos']
df_pos.loc[6, 'open_pos'] = df_out_6.loc[df_out_6.index[-1], 'open_pos']
df_pos.loc[7, 'open_pos'] = df_out_7.loc[df_out_7.index[-1], 'open_pos']
df_pos.loc[8, 'open_pos'] = df_out_8.loc[df_out_8.index[-1], 'open_pos']
df_pos.loc[9, 'open_pos'] = df_out_9.loc[df_out_9.index[-1], 'open_pos']
df_pos.loc[10, 'open_pos'] = df_out_10.loc[df_out_10.index[-1], 'open_pos']
df_pos.loc[11, 'open_pos'] = df_out_11.loc[df_out_11.index[-1], 'open_pos']
df_pos.loc[12, 'open_pos'] = df_out_12.loc[df_out_12.index[-1], 'open_pos']
df_pos.loc[13, 'open_pos'] = df_out_13.loc[df_out_13.index[-1], 'open_pos']
df_pos.loc[14, 'open_pos'] = df_out_14.loc[df_out_14.index[-1], 'open_pos']
df_pos.loc[15, 'open_pos'] = df_out_15.loc[df_out_15.index[-1], 'open_pos']
df_pos.loc[16, 'open_pos'] = df_out_16.loc[df_out_16.index[-1], 'open_pos']
df_pos.loc[17, 'open_pos'] = df_out_17.loc[df_out_17.index[-1], 'open_pos']
df_pos.loc[18, 'open_pos'] = df_out_18.loc[df_out_18.index[-1], 'open_pos']
df_pos.loc[19, 'open_pos'] = df_out_19.loc[df_out_19.index[-1], 'open_pos']
df_pos.loc[20, 'open_pos'] = df_out_20.loc[df_out_20.index[-1], 'open_pos']
df_pos.loc[21, 'open_pos'] = df_out_21.loc[df_out_21.index[-1], 'open_pos']
df_pos.loc[22, 'open_pos'] = df_out_22.loc[df_out_22.index[-1], 'open_pos']


df_pos
# Out:
#     open_pos
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False

# %%
# _______________________________________________________________________________________

# modificamos la columna open_pos de la ultima fila a False
df_out_9.loc[df_out_9.index[-1], 'open_pos'] = False

# y lo guardamos en pickle
df_out_9.to_pickle('df_out_9.pkl')
df_out_9.tail(5)

# _______________________________________________________________________________________
# Out:
#                     date     open     high      low   close in_condition_1  \
# 3459 2022-05-26 14:45:00  1843.15  1843.25  1840.45  1841.1          False
# 3460 2022-05-26 15:00:00  1841.10  1845.35  1841.05  1844.1          False
# 3461 2022-05-26 15:15:00  1844.10  1845.05  1843.10  1843.4          False
# 3462 2022-05-26 15:30:00  1843.40  1846.10  1839.15  1842.3          False
# 3463 2022-05-26 15:45:00     0.00     0.00     0.00     0.0          False
#
#      in_condition_2 out_condition_1 out_condition_2 signal_in signal_out  \
# 3459          False           False           False         0          0
# 3460          False           False           False         0          0
# 3461          False           False           False         0          0
# 3462          False           False           False         0          0
# 3463          False           False            True         0         -1
#
# ...

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_1.pkl')
display(df_out_1)
#df_out_1.tail(5)
# Out:
# Empty DataFrame
# Columns: [date, open, high, low, close, in_condition_1, in_condition_2, out_condition_1, out_condition_2, signal_in, signal_out, pos_before_order, order_sent, open_pos, filled_price, pnl]
# Index: []

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_2.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_3.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_4.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_5.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_6.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_7.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_8.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_9.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_10.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_11.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_12.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_13.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_14.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_15.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_16.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_17.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_18.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_19.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_20.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_21.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos monitorizar los datos de salida
df_out_1 = pd.read_pickle('df_out_22.pkl')
#display(df_out_1)
df_out_1.tail(5)

# %%
# podemos conectarnos en el canal 0 para monitorizar el portfolio y los trades
ib = IB()
util.startLoop()
ib.connect('127.0.0.1', 7497, clientId=0)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=0>

# %%
df_pos = pd.DataFrame(ib.positions())
df_pos
# Out:
#      account                                           contract  position  \
# 0  DU5317735  Future(conId=139214022, symbol='NG', lastTrade...       2.0
# 1  DU5317735  Future(conId=238666255, symbol='GC', lastTrade...       2.0
# 2  DU5317735  Future(conId=477836957, symbol='ES', lastTrade...       4.0
# 3  DU5317735  Future(conId=477836974, symbol='NQ', lastTrade...       2.0
#
#      avgCost
# 0   63947.37
# 1  193442.42
# 2  224558.40
# 3  291462.15

# %%
df_portfolio = pd.DataFrame(ib.portfolio())
df_portfolio
# Out:
#                                             contract  position   marketPrice  \
# 0  Future(conId=477836957, symbol='ES', lastTrade...       4.0   4496.750000
# 1  Future(conId=238666255, symbol='GC', lastTrade...       2.0   1933.400024
# 2  Future(conId=139214022, symbol='NG', lastTrade...       2.0      6.377000
# 3  Future(conId=477836974, symbol='NQ', lastTrade...       2.0  14550.502930
#
#    marketValue  averageCost  unrealizedPNL  realizedPNL    account
# 0    899350.00    224558.40        1116.40       991.40  DU5317735
# 1    386680.00    193442.42        -204.84       -89.68  DU5317735
# 2    127540.00     63947.37        -354.74      6421.56  DU5317735
# 3    582020.12    291462.15        -904.18      2449.20  DU5317735

# %%
df_trades = pd.DataFrame(ib.trades())
df_trades
# Out:
#                                              contract  \
# 0   {'secType': 'FUT', 'conId': 477836974, 'symbol...
# 1   {'secType': 'FUT', 'conId': 497954495, 'symbol...
# 2   {'secType': 'FUT', 'conId': 477836957, 'symbol...
# 3   {'secType': 'FUT', 'conId': 477836957, 'symbol...
# 4   {'secType': 'FUT', 'conId': 238666255, 'symbol...
# 5   {'secType': 'FUT', 'conId': 497954495, 'symbol...
# 6   {'secType': 'FUT', 'conId': 497954495, 'symbol...
# 7   {'secType': 'FUT', 'conId': 238666255, 'symbol...
# 8   {'secType': 'FUT', 'conId': 477836974, 'symbol...
# 9   {'secType': 'FUT', 'conId': 139214022, 'symbol...
# 10  {'secType': 'FUT', 'conId': 477836974, 'symbol...
# 11  {'secType': 'FUT', 'conId': 256019305, 'symbol...
# 12  {'secType': 'FUT', 'conId': 477836974, 'symbol...
# 13  {'secType': 'FUT', 'conId': 139214022, 'symbol...
# 14  {'secType': 'FUT', 'conId': 497954495, 'symbol...
# 15  {'secType': 'FUT', 'conId': 256019305, 'symbol...
# ...

# %%
df_opentrades = pd.DataFrame(ib.openTrades())
df_opentrades
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_fills = pd.DataFrame(ib.fills())
df_fills
# Out:
#                                              contract  \
# 0   Future(conId=256019305, symbol='CL', lastTrade...
# 1   Future(conId=238666255, symbol='GC', lastTrade...
# 2   Future(conId=477836974, symbol='NQ', lastTrade...
# 3   Future(conId=139214022, symbol='NG', lastTrade...
# 4   Future(conId=497954495, symbol='YM', lastTrade...
# 5   Future(conId=139214022, symbol='NG', lastTrade...
# 6   Future(conId=139214022, symbol='NG', lastTrade...
# 7   Future(conId=497954495, symbol='YM', lastTrade...
# 8   Future(conId=497954495, symbol='YM', lastTrade...
# 9   Future(conId=477836974, symbol='NQ', lastTrade...
# 10  Future(conId=477836974, symbol='NQ', lastTrade...
# 11  Future(conId=477836957, symbol='ES', lastTrade...
# 12  Future(conId=139214022, symbol='NG', lastTrade...
# 13  Future(conId=477836957, symbol='ES', lastTrade...
# 14  Future(conId=497954495, symbol='YM', lastTrade...
# 15  Future(conId=238666255, symbol='GC', lastTrade...
# ...

# %%
df_accountSummary = pd.DataFrame(ib.accountSummary())
df_accountSummary
# Out:
#       account                    tag       value currency modelCode
# 0   DU5317735            AccountType  INDIVIDUAL
# 1   DU5317735                Cushion    0.770955
# 2   DU5317735     DayTradesRemaining          -1
# 3   DU5317735  DayTradesRemainingT+1          -1
# 4   DU5317735  DayTradesRemainingT+2          -1
# ..        ...                    ...         ...      ...       ...
# 70        All           WarrantValue        0.00     BASE
# 71        All          FxCashBalance        0.00     BASE
# 72        All         AccountOrGroup         All     BASE
# 73        All           RealCurrency        BASE     BASE
# 74        All      IssuerOptionValue        0.00     BASE
#
# [75 rows x 5 columns]

# %%
df_commissionReportEvent = pd.DataFrame(ib.commissionReportEvent())
df_commissionReportEvent
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_executions = pd.DataFrame(ib.executions())
df_executions
# Out:
#                      execId                      time acctNumber exchange  \
# 0   0000e1a7.624f5ca7.01.01 2022-04-07 22:00:05+00:00  DU5317735    NYMEX
# 1   0000e1a7.624f5ca8.01.01 2022-04-07 22:00:05+00:00  DU5317735    NYMEX
# 2   0000e1a7.624f5caa.01.01 2022-04-07 22:00:05+00:00  DU5317735   GLOBEX
# 3   0000e1a7.624f5cab.01.01 2022-04-07 22:00:06+00:00  DU5317735    NYMEX
# 4   0000e1a7.624f5cac.01.01 2022-04-07 22:00:06+00:00  DU5317735    ECBOT
# 5   0000e1a7.624f5cad.01.01 2022-04-07 22:00:06+00:00  DU5317735    NYMEX
# 6   0000e1a7.624f5cae.01.01 2022-04-07 22:00:06+00:00  DU5317735    NYMEX
# 7   0000e1a7.624f5caf.01.01 2022-04-07 22:00:06+00:00  DU5317735    ECBOT
# 8   0000e1a7.624f5cb0.01.01 2022-04-07 22:00:06+00:00  DU5317735    ECBOT
# 9   0000e1a7.624f5cb1.01.01 2022-04-07 22:00:06+00:00  DU5317735   GLOBEX
# 10  0000e1a7.624f5cb2.01.01 2022-04-07 22:00:06+00:00  DU5317735   GLOBEX
# 11  0000e1a7.624f5cb3.01.01 2022-04-07 22:00:06+00:00  DU5317735   GLOBEX
# ...

# %%
def is_port_in_use(port):
    import socket
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        return s.connect_ex(('localhost', port)) == 0

# %%
is_port_in_use(1)
# Out:
# False

# %%
clientId 0 already in use?
# Out:
# Object `use` not found.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
# ...

# %%
clientId 0 already in use

# %%
ib.isConnected
# Out:
# <bound method IB.isConnected of <IB not connected>>

# %%
ib.disconnect
